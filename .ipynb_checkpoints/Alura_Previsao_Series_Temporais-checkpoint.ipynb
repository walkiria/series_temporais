# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Series-temporais-para-previsão" data-toc-modified-id="Series-temporais-para-previsão-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Series temporais para previsão</a></span><ul class="toc-item"><li><span><a href="#Prever-o-proximo-ponto" data-toc-modified-id="Prever-o-proximo-ponto-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Prever o proximo ponto</a></span></li><li><span><a href="#Prever-utilizando-os-ultimos-3-pontos" data-toc-modified-id="Prever-utilizando-os-ultimos-3-pontos-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Prever utilizando os ultimos 3 pontos</a></span></li><li><span><a href="#Estacionariedade" data-toc-modified-id="Estacionariedade-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Estacionariedade</a></span><ul class="toc-item"><li><span><a href="#Testes-subjetivos" data-toc-modified-id="Testes-subjetivos-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Testes subjetivos</a></span></li><li><span><a href="#Teste-ADF" data-toc-modified-id="Teste-ADF-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Teste ADF</a></span><ul class="toc-item"><li><span><a href="#Notas" data-toc-modified-id="Notas-1.3.2.1"><span class="toc-item-num">1.3.2.1&nbsp;&nbsp;</span>Notas</a></span></li></ul></li></ul></li><li><span><a href="#Predição" data-toc-modified-id="Predição-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Predição</a></span><ul class="toc-item"><li><span><a href="#Metodo-de-suavização-exponencial" data-toc-modified-id="Metodo-de-suavização-exponencial-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Metodo de suavização exponencial</a></span></li><li><span><a href="#Holt-winters" data-toc-modified-id="Holt-winters-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Holt winters</a></span></li></ul></li></ul></li><li><span><a href="#Autocorrelação" data-toc-modified-id="Autocorrelação-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Autocorrelação</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Autocorrelacoa-parcial" data-toc-modified-id="Autocorrelacoa-parcial-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Autocorrelacoa parcial</a></span><ul class="toc-item"><li><span><a href="#Notas" data-toc-modified-id="Notas-2.0.1.1"><span class="toc-item-num">2.0.1.1&nbsp;&nbsp;</span>Notas</a></span></li></ul></li></ul></li><li><span><a href="#Modelos-autorregressivos" data-toc-modified-id="Modelos-autorregressivos-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Modelos autorregressivos</a></span></li></ul></li><li><span><a href="#Medida-de-Performancemm" data-toc-modified-id="Medida-de-Performancemm-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Medida de Performancemm</a></span></li></ul></div>

# %% [markdown]
# # Series temporais para previsão

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
co2 = pd.read_csv('timeseries-aula1/co2.csv', sep='\t')

# %%
co2.head()
# Out:
#        data   media
# 0  1980.042  338.45
# 1  1980.125  339.15
# 2  1980.208  339.48
# 3  1980.292  339.87
# 4  1980.375  340.30

# %%
ax = plt.plot(co2['data'], co2['media'])
plt.title('Analise de Co2')
plt.xlabel('Data')
plt.ylabel('Média')

ax = ax

# %%
nasc = pd.read_csv('timeseries-aula1/nascimentos.csv')

# %%
nasc.head()
# Out:
#          data  n_nasc
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
# df2.plot()
nasc.data = pd.to_datetime(nasc.data)

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

plt.plot(nasc['data'], nasc['n_nasc'])

# %% [markdown]
# ## Prever o proximo ponto

# %%
media_carb = np.mean(co2.media)

# %%
df_carb = co2['data'][1] - co2['data'][0]

# %%
ax = plt.plot(co2['data'], co2['media'])
plt.plot(co2.iloc[-1,0]+df_carb, media_carb,"*") #plotando a media do co2
plt.title('Analise de Co2')
plt.xlabel('Data')
plt.ylabel('Média')

ax = ax

# %%
media_nasc = np.mean(nasc['n_nasc'])

# %%
dt_nasc = nasc['data'][1] - nasc['data'][0] # intervalo de tempo

# %%
ax = plt.plot(nasc['data'], nasc['n_nasc'])
plt.plot(nasc.iloc[-1,0]+dt_nasc, media_nasc,"*") #plotando a media do co2
plt.title('Analise de Co2')
plt.xlabel('Data')
plt.ylabel('Média')

ax = ax

# %%
# estimar a media dos ultimos 3 pontos 
co2.shape

media_tres_ult_pts = np.mean(co2['media'][474:476])
media_tres_ult_pts
# Out:
# 408.06

# %%
ax = plt.plot(co2['data'], co2['media'])
plt.plot(co2.iloc[-1,0]+df_carb, media_tres_ult_pts,"*") #plotando a media do co2
plt.title('Analise de Co2')
plt.xlabel('Data')
plt.ylabel('Média')

ax = ax

# %% [markdown]
# ## Prever utilizando os ultimos 3 pontos

# %%
# estimar a media dos ultimos 3 pontos 
nasc.shape

media_tres_ult_pts = np.mean(nasc['n_nasc'][362:364])
media_tres_ult_pts
# Out:
# 51.5

# %%
ax = plt.plot(nasc['data'], nasc['n_nasc'])
plt.plot(nasc.iloc[-1,0]+dt_nasc, media_tres_ult_pts,"*") #plotando a media do co2
plt.title('Previsão do numero de nascimentos ')
plt.xlabel('Data')
plt.ylabel('Média')

ax = ax

# %%
media_model_c =  co2.rolling(50).mean()

# %%
ax = plt.plot(co2['data'], co2['media'])
ax = plt.plot(media_model_c['data'], media_model_c['media'])

plt.title('Analise de Co2')
plt.xlabel('Data')
plt.ylabel('Média')

ax = ax

# %%
media_model_n =  nasc.rolling(5).mean()

# %%
ax = plt.plot(nasc['data'], nasc['n_nasc'])
ax = plt.plot(nasc['data'], media_model_n['n_nasc'])

plt.title('Analise de Co2')
plt.xlabel('Data')
plt.ylabel('Média')

ax = ax

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result_c = seasonal_decompose(co2.set_index('data'), period=10)

# %%
result_c.plot();

# %%
result_n = seasonal_decompose(nasc.set_index('data'), period=35)

# %%
result_n.plot();

# %% [markdown]
# * não tem sazonalidade mas tem tendencia

# %% [markdown]
# ## Estacionariedade

# %% [markdown]
# ### Testes subjetivos

# %%
# verifica estacionariedade - forma de uma gaussiana 
co2.media.hist()

# %% [markdown]
# * uma serie estacionaria parece uma gaussiana

# %%
divide = int(len(co2)/2)

# %%
x =co2.media.values

# %%
c1, c2  = x[0:divide], x[divide:]

# %%
# indicativos de não estacionariedade - medias diferentes
print('c1 media', c1.mean())
print('c2 media', c2.mean())
print('c1 var', c1.var())
print('c2 var', c2.var())
# Out:
# c1 media 352.31550420168065
# c2 media 387.816359832636
# c1 var 73.90219533401597
# c2 var 151.542490933282

# %% [markdown]
# * outra forma de verificar eh dividir a serie em algumas partes e verificar os valores de media, se os valores de media variam  temos um indicativo de nao estacionariedade.Outro indicativo é a variancia, valor alto de variancia indica nao estacionariedade

# %%
divide = int(len(nasc)/2)

# %%
x =nasc.n_nasc.values

# %%
c1, c2  = x[0:divide], x[divide:]

# %%
# indicativos de não estacionariedade - medias parecidas
print('c1 media', c1.mean())
print('c2 media', c2.mean())
print('c1 var', c1.var())
print('c2 var', c2.var())
# Out:
# c1 media 39.76373626373626
# c2 media 44.185792349726775
# c1 var 49.21341021615746
# c2 var 48.708650601690096

# %% [markdown]
# * Pequena variacao na media e pequena variação na variação. Indicativos de estacionariedade na base de nasc.

# %% [markdown]
# ### Teste ADF

# %%
from statsmodels.tsa.stattools import adfuller

# %%
resultados_c = adfuller(co2.media.values)

# %%
print('ADF', resultados_c[0])  # mais negativo mais indicativo de estacionariedade
print('p-value %f', resultados_c[1])
# Out:
# ADF 3.0368288291669945
# p-value %f 1.0

# %%
resultados_n = adfuller(nasc.n_nasc.values)

# %%
print('ADF', resultados_n[0])  # mais negativo mais indicativo de estacionariedade
print('p-value %f', resultados_n[1])
# Out:
# ADF -4.808291253559761
# p-value %f 5.243412990149905e-05

# %% [markdown]
# #### Notas

# %% [markdown]
# * Para que possamos fazer previsões em séries temporais, precisaremos garantir que elas sejam estacionárias.Caso contrário, será necessário levarmos em consideração características da série temporal que a tornam não-estacionária, no momento de previsão.
#
# * A diferenciação é uma transformação que pode ser aplicada para remover a dependência temporal dos dados, tornando a série estacionária.
#
# * A diferenciação é aplicada através da subtração de uma amostra atual dos dados por uma amostra anterior:
#     * diferenca(t) = serie(t) - serie(t-1)
# * Esta transformação deve ser revertida após a previsão para a obtenção dos valores corretos.
#     * serie_recuperada = diferenca(t) + serie(t-1)

# %%
serie_diferenciada = nasc['n_nasc'].diff()

# %%
# serie temporal original
plt.plot(nasc['data'],nasc['n_nasc'])
plt.ylabel('Nascimentos')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %%
# a figura da série após a diferenciação pode ser obtida por: ( tendencia removida)
plt.plot(nasc ['data'],serie_diferenciada)
plt.ylabel('Nascimentos')
plt.xlabel('Data')
# Out:
# Text(0.5, 0, 'Data')

# %% [markdown]
# ## Predição

# %% [markdown]
# ### Metodo de suavização exponencial

# %%
co2 = co2.set_index('data')

# %%
co2_train = co2[1980.042:2015]

# %%
co2_test = co2[2015:]

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
model_adj = SimpleExpSmoothing(co2_train).fit(smoothing_level=0.5)
# Out:
# /home/walkira/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:214: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
co2_test.shape
# Out:
# (57, 1)

# %%
model_prev = model_adj.forecast(57)
# Out:
# /home/walkira/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
plt.plot(co2_train)
plt.plot(co2_train.index, model_adj.fittedvalues.values)
plt.plot(co2_test, 'g')
plt.plot(co2_test.index,model_prev, 'r.' )

# %%
#nasc = nasc.set_index('data')
nasc_treino = nasc['1959-01-01':'1959-12-01']
nasc_teste = nasc['1959-12-01':]

model_adj = SimpleExpSmoothing(nasc_treino).fit(smoothing_level=0.5)

model_prev_suave =  model_adj.forecast(31)
# Out:
# /home/walkira/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %% [markdown]
# * estimativa baseada na media e na suavização dos pontos

# %% [markdown]
# ### Holt winters

# %% [markdown]
# * tbm de suavização exponencial, mas de 3 ordem;
# * modelo aditivo,
# * modelo multiplicativo
#
# * estima a cada ponto e atualiza a tendencia (alfa)
# * holtwinters: usa nivel, tendencia e sazonalidade
# * o holtwinters pergunta se a sazonalidade eh aditiva ou multiplicativa

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
modelo_ajustado = ExponentialSmoothing(co2_train.values, trend='additive', 
                     seasonal='additive', seasonal_periods=35).fit()
# Out:
# /home/walkira/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:744: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
co2.shape
# Out:
# (477, 1)

# %%
co2_test.shape
# Out:
# (57, 1)

# %%
modelo_prev = modelo_ajustado.predict(start=420, end =476)

# %%
plt.plot(co2_train)
plt.plot(co2_test,'g')
plt.plot(co2_test.index,modelo_prev, 'r.')

# %% [markdown]
# # Autocorrelação

# %% [markdown]
# * forma de verificar de sazonalidade: autocorrelacao

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(co2);

# %% [markdown]
# *  Os valores mais altos da autocorrelação indicam que existem partes semelhantes na série temporal por diversos atrasos.
# * parte azul região de confiança
# * valores acima da região azul temos mais confiança de que estão relacionados a sazonalidade

# %% [markdown]
# ### Autocorrelacoa parcial

# %%
from statsmodels.graphics.tsaplots import plot_pacf

# %%
plot_pacf(co2,lags=20);

# %% [markdown]
# * temos infos de correlacao

# %% [markdown]
# #### Notas

# %% [markdown]
#  * Temos 3 pontos da série: {𝑥𝑡
# , 𝑥𝑡−2, 𝑥𝑡−3}, através de FAC iremos obter a correlação entre
# 𝑥𝑡 𝑒 𝑥𝑡−3, porém o valor obtido da correlação foi influenciado pela correlação entre
# 𝑥𝑡−2 𝑒 𝑥𝑡−3. Através da FACP isso não acontece, a correlação entre 𝑥𝑡−1 𝑒 𝑥𝑡−3 não é
# influenciada por a correlação entre 𝑥𝑡−2 𝑒 𝑥𝑡−3

# %% [markdown]
# ## Modelos autorregressivos

# %% [markdown]
# * parece uma regressao linear comum, mas nao usa minimos quadrados, usa maxima verossimilhança;

# %%
from statsmodels.tsa.ar_model import AutoReg

# %%
lista = np.linspace(1, 40,40)

# %%
modelo_ajustado = AutoReg(co2_train.values, lags=lista, trend='c', seasonal=True, period=30).fit()

# %%
modelo_previsto = modelo_ajustado.predict(start =420, end=476 )

# %%
plt.plot(co2_train)
plt.plot(co2_test,'g')
plt.plot(co2_test.index,modelo_prev, 'r.')

# %%
modelo_ajustado = AutoReg(nasc_treino.values, lags=lista, trend='c', seasonal=True, period=35).fit()
modelo_previsto_ar = modelo_ajustado.predict(start=335,end=365)

# %% [markdown]
# # Medida de Performancemm

# %%
plt.plot(nasc_teste, 'g',label='valor_real')
plt.plot(nasc_teste.index, model_prev_suave,  'b-',label='prev_holt_winters')
plt.plot(nasc_teste.index, modelo_previsto_ar, 'r',label='prev_autoregressao')
plt.legend()

# %%
# calculo do erro de previsao 
erro_prev_s = nasc_teste['n_nasc'] - model_prev_suave
erro_prev_ar = nasc_teste['n_nasc'] - modelo_previsto_ar

# %%
plt.plot(erro_prev_s)
plt.plot(erro_prev_ar)

# %%
# erro mais proximo de zero melhor
print(np.mean(np.abs(erro_prev_s)))
print(np.mean(np.abs(erro_prev_ar)))
# Out:
# 7.022197566221869
# 5.496720548092115

# %%
# erro negativo ou positivo = quer dizer se to errando para mais ou para menos
print(np.mean(erro_prev_s))   
print(np.mean(erro_prev_ar))
# Out:
# -4.672160582221337
# -1.6083080804497984

# %% [markdown]
# * erro de previsao media = Com essa medida vamos ter um único valor que representa uma média dos erros, que pode ser negativa ou positiva, mostrando se estamos errando para baixo ou para cima.

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae = mean_absolute_error(nasc_teste['n_nasc'], modelo_previsto_ar)

# %%
mae
# Out:
# 5.496720548092115

# %%
# elevar ao quadrado - enfatiza o erro - deixa os erros maiores
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(nasc_teste['n_nasc'], modelo_previsto_ar)
# Out:
# 45.437394221812596

# %%
mean_squared_error(nasc_teste['n_nasc'], model_prev_suave)
# Out:
# 63.7761920175469

# %%
#
